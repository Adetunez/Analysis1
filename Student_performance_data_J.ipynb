# %%
import pandas as pd

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
import seaborn as sns

# %%
data = pd.read_csv('C:/JupyterNotebook/Student_performance_data.csv')

# %%
print(data.head())  # First 5 rows
# Out:
#    StudentID  Age  Gender  Ethnicity  ParentalEducation  StudyTimeWeekly  \
# 0       1001   17       1          0                  2        19.833723
# 1       1002   18       0          0                  1        15.408756
# 2       1003   15       0          2                  3         4.210570
# 3       1004   17       1          0                  3        10.028829
# 4       1005   17       1          0                  2         4.672495
#
#    Absences  Tutoring  ParentalSupport  Extracurricular  Sports  Music  \
# 0         7         1                2                0       0      1
# 1         0         0                1                0       0      0
# 2        26         0                2                0       0      0
# 3        14         0                3                1       0      0
# 4        17         1                3                0       0      0
#
#    Volunteering       GPA  GradeClass
# 0             0  2.929196         2.0
# ...

# %%
print(data.describe())  # Summary statistics
# Out:
#          StudentID          Age       Gender    Ethnicity  ParentalEducation  \
# count  2392.000000  2392.000000  2392.000000  2392.000000        2392.000000
# mean   2196.500000    16.468645     0.510870     0.877508           1.746237
# std     690.655244     1.123798     0.499986     1.028476           1.000411
# min    1001.000000    15.000000     0.000000     0.000000           0.000000
# 25%    1598.750000    15.000000     0.000000     0.000000           1.000000
# 50%    2196.500000    16.000000     1.000000     0.000000           2.000000
# 75%    2794.250000    17.000000     1.000000     2.000000           2.000000
# max    3392.000000    18.000000     1.000000     3.000000           4.000000
#
#        StudyTimeWeekly     Absences     Tutoring  ParentalSupport  \
# count      2392.000000  2392.000000  2392.000000      2392.000000
# mean          9.771992    14.541388     0.301421         2.122074
# std           5.652774     8.467417     0.458971         1.122813
# ...

# %%
# Handle missing values (if any)
data.fillna(method='ffill', inplace=True)
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_7928\397355435.py:2: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   data.fillna(method='ffill', inplace=True)

# %%
# Remove duplicates
data.drop_duplicates(inplace=True)

# %%
# Calculate basic statistics
print(data['Age'].mean())
# Out:
# 16.468645484949832

# %%
print(data['GradeClass'].median())
# Out:
# 4.0

# %%
# Calculate basic statistics
print(data['StudyTimeWeekly'].mean())
print(data['GPA'].median())
# Out:
# 9.771991919431738
# 1.8933926937866847

# %%
# Visualize the data
sns.histplot(data['Age'], kde=True)
plt.title('Age Distribution')
plt.show()

# %%
# Visualize the data
sns.histplot(data['GPA'], kde=True)
plt.title('Age')
plt.show()

# %%
sns.boxplot(x=data['GradeClass'])
plt.title('Grade Distribution')
plt.show()

# %%
# More advanced analysis (example: correlation matrix)
correlation_matrix = data.corr()
sns.heatmap(correlation_matrix, annot=True)
plt.show()

# %%
Student Performance data Summary

Data Characteristics:

Number of Students: 3392
Age Range: 15 - 18 years old
Gender Distribution:
Male: Likely More (based on Gender = 1)
Female: Likely Less (based on Gender = 0)
Ethnicity Distribution: (represented by values 0-3)
Parental Education Levels: (represented by values 0-4)

Academic Performance:
GPA Range: 0 - 4
Grade Class Distribution:
Visualized in the provided boxplot (Figure 19)

Time Commitment:
Study Time (Weekly):
Average: was calculated using data['StudyTimeWeekly'].mean() and it gave 9.771991919431738
Range: was calculated using data['StudyTimeWeekly'].min() and data['StudyTimeWeekly'].max() and it gave 19.97703746

Absences:
Range: 0 - 29
Tutoring:
Provided (value = 1) or Not Provided (value = 0)
Extracurricular Activities: Participation Information Available (value = 1) or Not Participating (value = 0)

Additional Activities:
Sports Participation Information Available (value = 1) or Not Participating (value = 0)
Music Participation Information Available (value = 1) or Not Participating (value = 0)
Volunteering Information Available (value = 1) or Not Participating (value = 0)

Further Analysis:
The provided code snippet (Figure 20) demonstrates how to calculate a correlation matrix to explore relationships between different variables.
